# %%
# !pip install pytrends
# !pip install quandl
import sys
sys.path.append('/content/')

from stocker import Stocker
#Classe Stocker disponível em https://github.com/WillKoehrsen/Data-Analysis/blob/master/stocker/stocker.py
#(fazer o Download e colocar na pasta do COLAB, ou do seu projeto)

# %%
microsoft = Stocker('MSFT',)
apple = Stocker('AAPL')
#petrobras = Stocker('PETR4.SA')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 00:00:00 to 2018-03-27 00:00:00.
# AAPL Stocker Initialized. Data covers 1980-12-12 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_history = microsoft.stock
stock_history.head()
# Out:
#         Date   Open   High  ...         ds         y  Daily Change
# 0 1986-03-13  25.50  29.25  ... 1986-03-13  0.064720      0.005779
# 1 1986-03-14  28.00  29.50  ... 1986-03-14  0.067031      0.002311
# 2 1986-03-17  29.00  29.75  ... 1986-03-17  0.068187      0.001156
# 3 1986-03-18  29.50  29.75  ... 1986-03-18  0.066454     -0.001734
# 4 1986-03-19  28.75  29.00  ... 1986-03-19  0.065298     -0.001156
#
# [5 rows x 16 columns]

# %%
microsoft.plot_stock(start_date='2015-01-01', end_date = '2018-01-16',plot_type='basic')
# Out:
# Maximum Adj. Close = 89.58 on 2018-01-12 00:00:00.
# Minimum Adj. Close = 37.45 on 2015-01-30 00:00:00.
# Current Adj. Close = 89.47 on 2018-03-27 00:00:00.

# %%
microsoft.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct', )
# Out:
# Maximum Daily Change = 2.08 on 2008-10-13 00:00:00.
# Minimum Daily Change = -3.34 on 2017-12-04 00:00:00.
# Current Daily Change = -5.47 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 591052200.00 on 2006-04-28 00:00:00.
# Minimum Adj. Volume = 7425503.00 on 2017-11-24 00:00:00.
# Current Adj. Volume = 53704562.00 on 2018-03-27 00:00:00.

# %%
microsoft.buy_and_hold(start_date='1986-03-13', 
                       end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 00:00:00 to 2018-01-16 00:00:00 for 100 shares = $8829.11

# %%
model, model_data = microsoft.create_prophet_model()

# %%
microsoft.changepoint_date_analysis()
# Out:
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 361 2016-09-01   55.966886 -1.231568
# 169 2015-11-27   51.353167 -1.051506
# 289 2016-05-20   48.886934  0.862231
# 313 2016-06-24   48.123981  0.532116
# 120 2015-09-18   41.122995  0.465999
