# %% [markdown]
# ## Nuclear
# ### Nuclear Power Plants
#
#
# ### Link
# https://www.kaggle.com/liananapalkova/nuclear-power-plants

# %% [markdown]
# # Importando Módulos / Download Dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.dates as mdates
import matplotlib as mpl
import kaggle
import os

# %%
def downloadKaggle(fName, pathFile,kaggleFile):
    kaggle.api.authenticate()
    kaggle.api.dataset_download_files(fName, path=pathFile, unzip=True)
    dirname = os.path.abspath('')
    arquivo=dirname + '/../datasets/'+kaggleFile
    return arquivo


dataset = 'liananapalkova/nuclear-power-plants'
data_file_name = 'energy-pop-exposure-nuclear-plants-locations_plants.csv'


arquivo = downloadKaggle(dataset,'../datasets',data_file_name)

# %%
df=pd.read_csv(arquivo,sep=',')

df.head(150)
# Out:
#      FID                        Region                   Country  \
# 0      0              Europe - Western                    SWEDEN
# 1      1              Europe - Western                     SPAIN
# 2      2               America - Latin                    BRAZIL
# 3      3            America - Northern  UNITED STATES OF AMERICA
# 4      4              Europe - Western                     SPAIN
# ..   ...                           ...                       ...
# 145  145  Europe - Central and Eastern        RUSSIAN FEDERATION
# 146  146            America - Northern  UNITED STATES OF AMERICA
# 147  147               Asia - Far East                     CHINA
# 148  148              Europe - Western                   GERMANY
# 149  149              Europe - Western                   FINLAND
#
#             Plant  NumReactor   Latitude   Longitude   p90_1200   p00_1200  \
# 0          AGESTA           1  59.206022   18.082872  187382000  188684000
# ...

# %%
# Verificando valores nulos
df.isnull().sum().sort_values(ascending=False)
# Out:
# Region      3
# p10_600     0
# p00r_75     0
# p10r_75     0
# p90_150     0
#            ..
# p10r_30     0
# p90_75      0
# p00_75      0
# p10_75      0
# p10r_300    0
# Length: 61, dtype: int64

# %%
# Variáveis numéricas.
df.describe()
# Out:
#               FID  NumReactor    Latitude   Longitude      p90_1200  \
# count  276.000000  276.000000  276.000000  276.000000  2.760000e+02
# mean   137.500000    2.329710   41.464873   -0.833154  2.634335e+08
# std     79.818544    1.533856   13.138551   75.441222  1.640597e+08
# min      0.000000    1.000000  -33.968002 -124.209044  3.558760e+05
# 25%     68.750000    1.000000   35.735645  -77.396385  1.463155e+08
# 50%    137.500000    2.000000   42.839200    4.720832  2.033275e+08
# 75%    206.250000    3.000000   49.579176   30.497974  3.788732e+08
# max    275.000000    9.000000   68.050658  166.539698  8.268430e+08
#
#            p00_1200      p10_1200     p90u_1200     p00u_1200     p10u_1200  \
# count  2.760000e+02  2.760000e+02  2.760000e+02  2.760000e+02  2.760000e+02
# mean   2.816791e+08  2.987191e+08  1.748656e+08  1.861499e+08  1.968991e+08
# std    1.833881e+08  1.994596e+08  9.068376e+07  9.689716e+07  1.015562e+08
# ...
