# %% [markdown]
# ## PYTHON JOURNEY MACHINE & DEEP LEARNING
# ### Trabalho prático usando Python
#
# ### Modelo de regressão linear simples

# %% [markdown]
# ![fig_densidade_celular.png](attachment:fig_densidade_celular.png)

# %%
# Importar as bibliotecas

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import math

# %%
# Importar os dados

df = pd.read_excel(r'C:\Users\regin\FIAP\Shift\Imersao_Python\trab4\densidade_celular.xlsx')

# %%
df.head()
# Out:
#     Ano  densidade  log(densidade)
# 0  1998        4.4        0.643453
# 1  1999        8.9        0.949390
# 2  2000       13.5        1.130334
# 3  2001       16.4        1.214844
# 4  2002       19.7        1.294466

# %%
# Gráfico de dispersão
plt.scatter('Ano', 'densidade', data=df)
plt.xlabel("Ano")
plt.ylabel("Densidade")
plt.title("Scatter Plot Densidade de celular vs Ano",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Scatter Plot Densidade de celular vs Ano')

# %%
sns.jointplot(x='Ano',y='densidade',data=df,kind='reg')

# %%
# Definir a variável resposta (Y) e a preditora (X)
X = df[['Ano']]

y = df[['densidade']]

# %%
# ajustando o modelo
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df['densidade_estimada'] = lm.predict(X)

# %%
df["Residuos"] = df['densidade'] - df['densidade_estimada']

# %%
sns.jointplot(x='Ano',y='densidade',data=df,kind='resid')

# %%
df.head(9)
# Out:
#     Ano  densidade  log(densidade)  densidade_estimada  Residuos
# 0  1998        4.4        0.643453            0.766667  3.633333
# 1  1999        8.9        0.949390            6.808333  2.091667
# 2  2000       13.5        1.130334           12.850000  0.650000
# 3  2001       16.4        1.214844           18.891667 -2.491667
# 4  2002       19.7        1.294466           24.933333 -5.233333
# 5  2003       25.8        1.411620           30.975000 -5.175000
# 6  2004       35.9        1.555094           37.016667 -1.116667
# 7  2005       46.6        1.668386           43.058333  3.541667
# 8  2006       53.2        1.725912           49.100000  4.100000

# %%
# Calcular o log10 da densidade
df['logdensidade'] = np.log(df['densidade'])

# %%
sns.jointplot(x='Ano', y='logdensidade', data=df, kind='reg')

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
# Definir a variável resposta (Y) e a preditora (X)
X1 = df[['Ano']]

y1 = df[['logdensidade']]

# %%
# ajustando o modelo
lm.fit(X1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Itercepto do modelo
print(lm.intercept_)
# Out:
# [-575.80046188]

# %%
df['logdensidade_estimada'] = lm.predict(X1)

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df.round(4)
# Out:
#      Coefficient
# Ano       0.2891

# %%
predictions = lm.predict(X1)

# %%
from sklearn.metrics import r2_score

# %%
print('R2:', r2_score(y1, predictions))
# Out:
# R2: 0.9617331193264681

# %%
df['densidade_estimada1'] = np.exp(-575.80 + 0.2891*df['Ano'])

# %%
df.head(9)
# Out:
#     Ano  densidade  log(densidade)  densidade_estimada  Residuos  \
# 0  1998        4.4        0.643453            0.766667  3.633333
# 1  1999        8.9        0.949390            6.808333  2.091667
# 2  2000       13.5        1.130334           12.850000  0.650000
# 3  2001       16.4        1.214844           18.891667 -2.491667
# 4  2002       19.7        1.294466           24.933333 -5.233333
# 5  2003       25.8        1.411620           30.975000 -5.175000
# 6  2004       35.9        1.555094           37.016667 -1.116667
# 7  2005       46.6        1.668386           43.058333  3.541667
# 8  2006       53.2        1.725912           49.100000  4.100000
#
#    logdensidade  logdensidade_estimada  densidade_estimada1
# 0      1.481605               1.809736             6.182978
# 1      2.186051               2.098830             8.255668
# 2      2.602690               2.387925            11.023176
# 3      2.797281               2.677019            14.718423
# 4      2.980619               2.966113            19.652410
# 5      3.250374               3.255207            26.240395
# 6      3.580737               3.544301            35.036837
# 7      3.841601               3.833395            46.782070
# 8      3.974058               4.122490            62.464600

# %%
sns.jointplot(x='Ano', y='logdensidade', data=df, kind='resid')

# %%
df.head(9)
# Out:
#     Ano  densidade  log(densidade)  densidade_estimada  Residuos  \
# 0  1998        4.4        0.643453            0.766667  3.633333
# 1  1999        8.9        0.949390            6.808333  2.091667
# 2  2000       13.5        1.130334           12.850000  0.650000
# 3  2001       16.4        1.214844           18.891667 -2.491667
# 4  2002       19.7        1.294466           24.933333 -5.233333
# 5  2003       25.8        1.411620           30.975000 -5.175000
# 6  2004       35.9        1.555094           37.016667 -1.116667
# 7  2005       46.6        1.668386           43.058333  3.541667
# 8  2006       53.2        1.725912           49.100000  4.100000
#
#    logdensidade  logdensidade_estimada  densidade_estimada1
# 0      1.481605               1.809736             6.182978
# 1      2.186051               2.098830             8.255668
# 2      2.602690               2.387925            11.023176
# 3      2.797281               2.677019            14.718423
# 4      2.980619               2.966113            19.652410
# 5      3.250374               3.255207            26.240395
# 6      3.580737               3.544301            35.036837
# 7      3.841601               3.833395            46.782070
# 8      3.974058               4.122490            62.464600
