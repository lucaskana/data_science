# %% [markdown]
# ## PYTHON JOURNEY MACHINE & DEEP LEARNING
# ### Trabalho prático usando o Python
# ### Noções de probabilidade

# %% [markdown]
# ### Definição 1
#
# “A probabilidade simplesmente determina qual é a chance de algo acontecer.”
#
# “Toda vez que não temos certeza sobre o resultado de algum evento, estamos tratando da probabilidade de certos resultados acontecerem—ou quais as chances de eles acontecerem.”
#
# Fonte:https://pt.khanacademy.org/math/probability/probability-geometry/probability-basics/a/probability-the-basics
#
#
# ### Definição 2
#
# “As frequências relativas são estimativas de probabilidade de ocorrência de certos eventos de interesse.
# Com suposições adequadas, e sem observamos diretamente o fenômeno aleatório de interesse, podemos criar
# um modelo teórico que reproduza de maneira razoável a distribuição das frequências, quando o fenômeno é
# observado diretamente. Tais modelos são chamados de modelos probabilísticos.”
#
# (Bussab, WO e Morettin, PA, Estatística Básica. 5 ed. São Paulo: Saraiva, 2002, página 103).
#
#
# ![exemplo2_prob_freq.png](attachment:exemplo2_prob_freq.png)

# %% [markdown]
# ### Propriedades
#
# (1) Para cada experiência define-se um espaço amostral
# (2) Probabilidade de um evento E:  0 ≤ P(E) ≤ 1
# (3) P(S) = Soma das probabilidades dos eventos simples = 1

# %% [markdown]
# ### Exemplo 1: Qual a probabilidade de ganhar o prêmio máximo da Mega Sena com um único jogo de seis dezenas?
#
# ![megasena.png](attachment:megasena.png)

# %%
# Espaço amostral

omega = {(1,2,3,4,5,6), (1,2,3,4,5,7), (1,2,3,4,5,8) .... (????)}

# %% [markdown]
# ### Método para resolver problema relacionado a contagem
#
# ![analise_combinatoria.png](attachment:analise_combinatoria.png)

# %%
# Importar numpy
import numpy as np

# %%
# Fatorial
0! = 1
1! = 1
2! = 2 x 1 = 2
3! = 3 x 2 x 1 = 6

# %%
# Solução
print('0!=',np.math.factorial(3))
# Out:
# 0!= 6

# %%
n = 60
p= 6
difnp = n - p
print('n!=',np.math.factorial(n))
print('p!=',np.math.factorial(p))      
print('difnp!=',np.math.factorial(difnp))
print('combinacoes=',np.math.factorial(n)/(np.math.factorial(difnp)*np.math.factorial(p)))
# Out:
# n!= 8320987112741390144276341183223364380754172606361245952449277696409600000000000000
# p!= 720
# difnp!= 230843697339241380472092742683027581083278564571807941132288000000000000
# combinacoes= 50063860.0

# %%
# Cálculo da probabilidade de ganhar com um único jogo da Mega Sena

prob = 1/np.math.factorial(n)/(np.math.factorial(difnp)*np.math.factorial(p))
print(prob)
# Out:
# 7.230604923382542e-157

# %% [markdown]
# ## Distribuição de probabilidade
# ### Variável discreta

# %% [markdown]
# ### Exemplo
#
# Construir o modelo preditivo a fim de prever o resultado de partidas do campeonato brasileiro.
#
# Considerando que a quantidade de gols marcados (K) em uma partida de futebol do Campeonato Brasileiro de Futebol (Brasileirão) em 2018 seja uma variável aleatória que segue a distribuição de Poisson com média de gols igual a 𝜆.
#
# Calcule a probabilidade de ocorrer k = 0, 1, 2, 3, 4, 5, 6 e 7.
#
#
# ![distr_poisson.png](attachment:distr_poisson.png)

# %%
# importar as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
# Importar os dados do Cartola FC de 2018 para estimar a média de gols.

cartolafc = pd.read_excel(r'C:\Users\regin\FIAP\Shift\Imersao_Python\Turma3\trab2\cartola_fc_2018.xlsx')

# %%
cartolafc.head()
# Out:
#    game  round                date           home_team  score  gol_m  gol_v  \
# 0     1      1  14/04/2018 - 16:00       Cruzeiro - MG  0 x 1      0      1
# 1     2      1  15/04/2018 - 19:00       Atlético - PR  5 x 1      5      1
# 2     3      1  15/04/2018 - 11:00        América - MG  3 x 0      3      0
# 3     4      1  14/04/2018 - 19:00        Vitória - BA  2 x 2      2      2
# 4     5      1  15/04/2018 - 16:00  Vasco da Gama - RJ  2 x 1      2      1
#
#    gols             arena                                Local
# 0     1       Grêmio - RS       Mineirão - Belo Horizonte - MG
# 1     6  Chapecoense - SC     Arena da Baixada - Curitiba - PR
# 2     3        Sport - PE  Independência - Belo Horizonte - MG
# 3     4     Flamengo - RJ      Manoel Barradas - Salvador - BA
# 4     3     Atlético - MG   São Januário - Rio de Janeiro - RJ

# %%
cartolafc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   game       380 non-null    int64
#  1   round      380 non-null    int64
#  2   date       380 non-null    object
#  3   home_team  380 non-null    object
#  4   score      380 non-null    object
#  5   gol_m      380 non-null    int64
#  6   gol_v      380 non-null    int64
#  7   gols       380 non-null    int64
#  8   arena      380 non-null    object
#  9   Local      380 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 29.8+ KB

# %%
cartolafc.describe().round(2)
# Out:
#          game   round   gol_m   gol_v    gols
# count  380.00  380.00  380.00  380.00  380.00
# mean   190.50   19.50    1.38    0.79    2.18
# std    109.84   10.98    1.12    0.91    1.48
# min      1.00    1.00    0.00    0.00    0.00
# 25%     95.75   10.00    1.00    0.00    1.00
# 50%    190.50   19.50    1.00    1.00    2.00
# 75%    285.25   29.00    2.00    1.00    3.00
# max    380.00   38.00    5.00    4.00    7.00

# %%
media_gols = cartolafc['gols'].mean()
print(media_gols)
# Out:
# 2.1763157894736844

# %%
# Gráfico da variável gols
sn.countplot(x='gols', data=cartolafc)
# Out:
# <AxesSubplot:xlabel='gols', ylabel='count'>

# %%
# Calcular a média de gols

media_gols = cartolafc['gols'].mean()
print(media_gols)
# Out:
# 2.1763157894736844

# %%
# Qual a probabilidade de ocorrer 0 gol?
# P(K=0) = 0.113413528037031
lamb = media_gols
euler = 2.71828
k=0
numerador = (euler**(-lamb))*lamb**k
denominador = np.math.factorial(k)
prob_k = numerador/denominador
print('prob=', prob_k)
# Out:
# prob= 0.11345893365287599

# %%
# Qual a probabilidade de ocorrer 1 gol?
# P(K=1) = 0.24682365180690696
lamb = media_gols
euler = 2.71828
k=1
numerador = (euler**(-lamb))*lamb**k
denominador = np.math.factorial(k)
prob_k = numerador/denominador
print('prob=', prob_k)
# Out:
# prob= 0.2469224687656012

# %%
# Qual a probabilidade de ocorrer 2 gol?
# P(K=2) = 0.26858310532146323
lamb = media_gols
euler = 2.71828
k=2
numerador = (euler**(-lamb))*lamb**k
denominador = np.math.factorial(k)
prob_k = numerador/denominador
print('prob=', prob_k)
# Out:
# prob= 0.26869063377520025

# %%
# Qual a probabilidade de ocorrer 3 gol?
# P(K=3) = 0.19484055096565803
lamb = media_gols
euler = 2.71828
k=3
numerador = (euler**(-lamb))*lamb**k
denominador = np.math.factorial(k)
prob_k = numerador/denominador
print('prob=', prob_k)
# Out:
# prob= 0.19491855625621987

# %%
#instalar: pip install empiricaldist
# !pip install empiricaldist
from empiricaldist import Pmf

def poisson_pmf (lam,qs):
    ps = poisson(lam).pmf(qs)
    pmf = Pmf(ps,qs)
    return pmf
# Out:
# Collecting empiricaldist
#   Using cached empiricaldist-0.6.2.tar.gz (9.5 kB)
# Building wheels for collected packages: empiricaldist
#   Building wheel for empiricaldist (setup.py): started
#   Building wheel for empiricaldist (setup.py): finished with status 'done'
#   Created wheel for empiricaldist: filename=empiricaldist-0.6.2-py3-none-any.whl size=10733 sha256=1fd06a73a5d012745e71da019bf51c38714a3cdf3341bb3dec0525008f813967
#   Stored in directory: c:\users\regin\appdata\local\pip\cache\wheels\2a\ed\75\39cda0596e8f5606df54fb63969c565b49d23869ee64a62435
# Successfully built empiricaldist
# Installing collected packages: empiricaldist
# Successfully installed empiricaldist-0.6.2

# %%
from scipy.stats import poisson

# Probanility Mass Function
from empiricaldist import Pmf
def poisson_pmf(lam, qs):
    ps=poisson(lam).pmf(qs)
    pmf=Pmf(ps,qs)
    return pmf

# %%
lam = media_gols
goals=np.arange(10)
pmf_goals = poisson_pmf(lam,goals)
print(pmf_goals)
# Out:
# 0    0.113459
# 1    0.246922
# 2    0.268690
# 3    0.194918
# 4    0.106051
# 5    0.046160
# 6    0.016743
# 7    0.005205
# 8    0.001416
# 9    0.000342
# Name: , dtype: float64

# %%
# Probanility Mass Function
lam = 2
goals=np.arange(10)
pmf_goals = poisson_pmf(lam,goals)
print(pmf_goals)
# Out:
# 0    0.135335
# 1    0.270671
# 2    0.270671
# 3    0.180447
# 4    0.090224
# 5    0.036089
# 6    0.012030
# 7    0.003437
# 8    0.000859
# 9    0.000191
# Name: , dtype: float64

# %% [markdown]
# ## Distribuição de probabilidade
# ### Variável contínua
#
# ![distr_normal.png](attachment:distr_normal.png)

# %% [markdown]
# ## Distribuição Normal Padrão ou Normal Reduzida
#
# ![dist_norm_padr.png](attachment:dist_norm_padr.png)

# %%
# Use a Tabela Normal Padrão para encontrar a probabilidade:

1) P(Z > 0) = 0.50

2) P(Z < 0) = 0.50

3) P(Z > 1.96) = 0.50 -0.475 = 0.025

4) P(Z < -1.96) = 0.50 - 0.475 = 0.025

5) P(-1.96 < Z < +1.96) = 0.475 + 0.475 = 0.95

# %% [markdown]
# ## Normalização dos dados
#
# ![padr_variaveis.png](attachment:padr_variaveis.png)

# %%
# Importar os dados de ingestão de sal da Pesquisa Nacional de Saúde (PNS) 2013 do IBGE

sal = pd.read_excel(r'C:\Users\regin\FIAP\Shift\Imersao_Python\Turma3\trab2\sal_lab1.xlsx')

# %%
sal.head()
# Out:
#    ID  Ingestao_Sal        regiao        p75
# 0   1          8.56  Centro-Oeste  Menor p75
# 1   2          7.44         Norte  Menor p75
# 2   3         10.30      Nordeste  Menor p75
# 3   4          7.68      Nordeste  Menor p75
# 4   7         10.08      Nordeste  Menor p75

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8080 entries, 0 to 8079
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            8080 non-null   int64
#  1   Ingestao_Sal  8080 non-null   float64
#  2   regiao        8080 non-null   object
#  3   p75           8080 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 252.6+ KB

# %%
sal.isna().sum()
# Out:
# ID              0
# Ingestao_Sal    0
# regiao          0
# p75             0
# dtype: int64

# %%
sal.describe()
# Out:
#                 ID  Ingestao_Sal
# count  8080.000000   8080.000000
# mean   4469.616708      9.136048
# std    2576.914687      2.316944
# min       1.000000      1.130000
# 25%    2237.750000      7.625587
# 50%    4473.000000      9.022889
# 75%    6716.500000     10.549696
# max    8949.000000     28.278044

# %%
# Histograma da Ingestão de Sal

plt.hist(sal['Ingestao_Sal'])
# Out:
# (array([5.800e+01, 9.500e+02, 3.408e+03, 2.797e+03, 7.480e+02, 1.010e+02,
#         1.300e+01, 3.000e+00, 1.000e+00, 1.000e+00]),
#  array([ 1.13     ,  3.8448044,  6.5596088,  9.2744132, 11.9892176,
#         14.704022 , 17.4188264, 20.1336308, 22.8484352, 25.5632396,
#         28.278044 ]),
#  <BarContainer object of 10 artists>)

# %%
# Análise descritiva da Ingestão de sal

# %%
# Ingestão de Sal tem média 9,14g/dia e desvio padrão de 2.32g/dia

# Criar a variável z_score_sal com média 0 e variância igual a 1
sal['zscore_sal'] = (sal['Ingestao_Sal'] - 9.14)/2.32

# %%
sal.head()
# Out:
#    ID  Ingestao_Sal        regiao        p75  zscore_sal
# 0   1          8.56  Centro-Oeste  Menor p75   -0.250000
# 1   2          7.44         Norte  Menor p75   -0.732759
# 2   3         10.30      Nordeste  Menor p75    0.500000
# 3   4          7.68      Nordeste  Menor p75   -0.629310
# 4   7         10.08      Nordeste  Menor p75    0.405172

# %%
sal.describe().round(2)
# Out:
#             ID  Ingestao_Sal  zscore_sal
# count  8080.00       8080.00     8080.00
# mean   4469.62          9.14       -0.00
# std    2576.91          2.32        1.00
# min       1.00          1.13       -3.45
# 25%    2237.75          7.63       -0.65
# 50%    4473.00          9.02       -0.05
# 75%    6716.50         10.55        0.61
# max    8949.00         28.28        8.25

# %%
# Gráfico histograma da Ingestão de Sal e Z_score_sal
plt.subplot(1,2,1)
plt.hist(sal['Ingestao_Sal'], bins=10)
plt.subplot(1,2,2)
plt.hist(sal['zscore_sal'], bins=10)
# Out:
# (array([5.800e+01, 9.500e+02, 3.408e+03, 2.797e+03, 7.480e+02, 1.010e+02,
#         1.300e+01, 3.000e+00, 1.000e+00, 1.000e+00]),
#  array([-3.45258621, -2.2824119 , -1.11223759,  0.05793672,  1.22811103,
#          2.39828534,  3.56845966,  4.73863397,  5.90880828,  7.07898259,
#          8.2491569 ]),
#  <BarContainer object of 10 artists>)

# %%
# Criar a variável padronizada da Ingestão de Sal usando o critério do Máximo e Mínimo

sal['sal_normalizado'] = (sal['Ingestao_Sal'] -  1.13)/(28.28 - 1.13)

# %%
sal.describe().round(2)
# Out:
#             ID  Ingestao_Sal  zscore_sal  sal_normalizado
# count  8080.00       8080.00     8080.00          8080.00
# mean   4469.62          9.14       -0.00             0.29
# std    2576.91          2.32        1.00             0.09
# min       1.00          1.13       -3.45             0.00
# 25%    2237.75          7.63       -0.65             0.24
# 50%    4473.00          9.02       -0.05             0.29
# 75%    6716.50         10.55        0.61             0.35
# max    8949.00         28.28        8.25             1.00

# %%
# Fazer o gráfico histograma da Ingestão de Sal e sal_normalizada
plt.subplot(1,3,1)
plt.hist(sal['Ingestao_Sal'], bins=10)
plt.subplot(1,3,2)
plt.hist(sal['zscore_sal'], bins=10)
plt.subplot(1,3,3)
plt.hist(sal['sal_normalizado'], bins=10)
# Out:
# (array([5.800e+01, 9.500e+02, 3.408e+03, 2.797e+03, 7.480e+02, 1.010e+02,
#         1.300e+01, 3.000e+00, 1.000e+00, 1.000e+00]),
#  array([0.        , 0.0999928 , 0.19998559, 0.29997839, 0.39997118,
#         0.49996398, 0.59995677, 0.69994957, 0.79994236, 0.89993516,
#         0.99992796]),
#  <BarContainer object of 10 artists>)
